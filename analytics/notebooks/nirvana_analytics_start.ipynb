# %% [markdown]
# # Nirvana Analytics Start
#
# Read-only sandbox for sales forecasts, expense anomaly checks, inventory velocity, and shop comparisons.

# %%
from analytics.nirvana_analytics.data_loader import load_core_frames

frames = load_core_frames(limit=5000)
{
    'sales': frames.sales.shape,
    'ledger': frames.ledger.shape,
    'inventory': frames.inventory.shape,
    'operations': frames.operations.shape,
}

# %%
from analytics.nirvana_analytics.demand_forecast import run as forecast

forecast(days=90, horizon=14, shop_id=None)
